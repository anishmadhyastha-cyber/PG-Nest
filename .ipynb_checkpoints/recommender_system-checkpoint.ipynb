# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
accomodations=pd.read_csv('data.csv')

# %%
accomodations.head(2)
# Out:
#    pg_id                   pg_name  \
# 0  PG001  SVC Galaxy PG for Ladies
# 1  PG002    Study Home PG For Boys
#
#                                         full_address     locality  \
# 0  Nagenahalli Main Rd, Opposite BMSIT College, B...  Nagenahalli
# 1    Doddaballapura Main Road, Near BMSIT, Bengaluru  Nagenahalli
#
#            nearest_bus_stop  distance_to_bmsit_km  distance_to_bus_stop_km  \
# 0  Yelahanka Police Station                   0.3                      0.8
# 1      Yelahanka NES Office                   5.3                      0.3
#
#                 nearest_metro  distance_to_metro_km  monthly_rent  ...   ac  \
# 0  Yelahanka Metro (Upcoming)                   8.8          9000  ...  Yes
# 1  Yelahanka Metro (Upcoming)                   8.3          6500  ...  Yes
#
#   laundry parking locality_safety_rating student_community_present  \
# 0      No     Yes                    4.6                       Yes
# ...

# %%
accomodation.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 accomodation.shape
#
# NameError: name 'accomodation' is not defined

# %%
accomodations.shape
# Out:
# (70, 27)

# %%
accomodations.columns
# Out:
# Index(['pg_id', 'pg_name', 'full_address', 'locality', 'nearest_bus_stop',
#        'distance_to_bmsit_km', 'distance_to_bus_stop_km', 'nearest_metro',
#        'distance_to_metro_km', 'monthly_rent', 'security_deposit',
#        'additional_charges', 'room_type', 'furnishing_status', 'bathroom_type',
#        'wifi', 'food_included', 'ac', 'laundry', 'parking',
#        'locality_safety_rating', 'student_community_present',
#        'landlord_responsiveness_rating', 'food_rating',
#        'overall_student_rating', 'source', 'verification_link'],
#       dtype='object')

# %%
accomodations[['pg_name','locality','nearest_bus_stop','distance_to_bmsit_km', 'distance_to_bus_stop_km', 'monthly_rent', 'security_deposit',
       'additional_charges', 'room_type', 'furnishing_status', 'bathroom_type',
       'wifi', 'food_included', 'ac', 'laundry', 'parking',
       'locality_safety_rating', 'student_community_present',
       'landlord_responsiveness_rating', 'food_rating',
       'overall_student_rating']]
# Out:
#                      pg_name            locality          nearest_bus_stop  \
# 0   SVC Galaxy PG for Ladies         Nagenahalli  Yelahanka Police Station
# 1     Study Home PG For Boys         Nagenahalli      Yelahanka NES Office
# 2       Sri Rama PG for Boys         Nagenahalli         Allalasandra Gate
# 3    Happy Homes PG for Boys          Avalahalli           Aradeshanahalli
# 4       Maa Anjani Ladies PG  Yelahanka New Town         Allalasandra Gate
# ..                       ...                 ...                       ...
# 65          SVR Luxury PG 65        Attur Layout                Avalahalli
# 66           Vivek Hostel 66       Bagalur Cross      Yelahanka NES Office
# 67           Annapurna PG 67         Nagenahalli           Anantapura Gate
# 68     Royal Residency PG 68  Chikka Bommasandra               Rajanukunte
# 69          Elite Stay PG 69         Rajanukunte              Honnenahalli
#
#     distance_to_bmsit_km  distance_to_bus_stop_km  monthly_rent  \
# ...
